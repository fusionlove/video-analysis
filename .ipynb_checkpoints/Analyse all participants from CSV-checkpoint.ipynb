# %%
import scipy
import pickle, random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import sleep
from skimage.util import img_as_float
from sklearn.model_selection import train_test_split

import sys
sys.path.append("D:/Dropbox/tome/python/fx")
#import fx

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import skimage
from skimage.color import rgb2hsv
from skimage.io import imread
from skimage.io import imsave
import image_analysis as IA

import json


pd.set_option('display.max_rows', 20000)

# %%
import csv


# Load the CSV file with all trial info into a list of dictionaries

c = 'data/csv-files-from-experiment/cleaner_df.csv'

with open(c) as f:
    boxes = [{k: v for k, v in row.items()}
        for row in csv.DictReader(f, skipinitialspace=True, delimiter=',')]

# %%
hsv_distances, trial_details = IA.run_analysis_from_csv_all_participants(boxes)
# Out:
# 44 - trial 1: frame 150 at 5 seconds data/frames/HH4/frame0150.jpg HH4 Cold4
# 45 - trial 2: frame 300 at 10 seconds data/frames/HH4/frame0300.jpg HH4 Warm5
# 46 - trial 3: frame 450 at 15 seconds data/frames/HH4/frame0450.jpg HH4 Cold4
# 47 - trial 4: frame 600 at 20 seconds data/frames/HH4/frame0600.jpg HH4 Warm1
# 48 - trial 5: frame 750 at 25 seconds data/frames/HH4/frame0750.jpg HH4 Warm2
# 49 - trial 6: frame 900 at 30 seconds data/frames/HH4/frame0900.jpg HH4 Warm2
# 50 - trial 7: frame 1050 at 35 seconds data/frames/HH4/frame1050.jpg HH4 Cold6
# 51 - trial 8: frame 1200 at 40 seconds data/frames/HH4/frame1200.jpg HH4 Warm4
# 52 - trial 9: frame 1350 at 45 seconds data/frames/HH4/frame1350.jpg HH4 Cold4
# 53 - trial 10: frame 1500 at 50 seconds data/frames/HH4/frame1500.jpg HH4 Cold2
# 54 - trial 11: frame 1650 at 55 seconds data/frames/HH4/frame1650.jpg HH4 Cold3
# New video!
# 55 - trial 1: frame 150 at 5 seconds data/frames/HH1/frame0150.jpg HH1 Warm6
# ...

# %%
df=pd.DataFrame(trial_details)

# %%
df
# Out:
#     box_index  trial_index video      box_colour box_name  hsv_distance  \
# 0          45            1   HH4    [0, 134, 56]    Cold4      0.922490
# 1          46            2   HH4   [255, 79, 33]    Warm5      0.965964
# 2          47            3   HH4    [0, 134, 56]    Cold4      0.954205
# 3          48            4   HH4  [219, 210, 52]    Warm1      0.872414
# 4          49            5   HH4    [251, 0, 27]    Warm2      1.245639
# 5          50            6   HH4    [251, 0, 27]    Warm2      1.150618
# 6          51            7   HH4    [52, 0, 107]    Cold6      0.943621
# 7          52            8   HH4   [104, 27, 10]    Warm4      0.831256
# 8          53            9   HH4    [0, 134, 56]    Cold4      0.870681
# 9          54           10   HH4   [63, 186, 42]    Cold2      0.794364
# 10         55           11   HH4   [0, 208, 241]    Cold3      1.072362
# 11         56           12   HH1    [161, 6, 85]    Warm6      0.754719
#
# ...

# %%
df.to_csv('data/results_1.csv')
