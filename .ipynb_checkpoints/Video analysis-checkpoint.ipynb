# %%
import scipy
import pickle, random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import sys
sys.path.append("D:/Dropbox/tome/python/fx")
#import fx

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from skimage.color import rgb2hsv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import cv2
fv = "videos/HAHV1.mp4"
vidcap = cv2.VideoCapture(fv)
success,image = vidcap.read()

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.3.56-cp37-cp37m-win_amd64.whl (34.9 MB)
# Requirement already satisfied: numpy>=1.14.5 in d:\anaconda\envs\three\lib\site-packages (from opencv-python) (1.21.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.3.56

# %%
image
# Out:
# array([[[135,  46,  93],
#         [135,  46,  93],
#         [135,  46,  93],
#         ...,
#         [176,  30,  77],
#         [176,  30,  77],
#         [176,  30,  77]],
#
#        [[146,  57, 104],
#         [146,  57, 104],
#         [146,  57, 104],
#         ...,
#         [189,  43,  90],
#         [189,  43,  90],
#         [189,  43,  90]],
#
#        [[151, 115, 158],
#         [151, 115, 158],
#         [151, 115, 158],
#         ...,
#         [144, 120, 149],
#         [144, 120, 149],
#         [144, 120, 149]],
#
#        ...,
#
#        [[176, 135, 126],
#         [177, 136, 127],
#         [182, 141, 132],
#         ...,
#         [187, 140, 137],
#         [191, 144, 141],
#         [192, 145, 142]],
#
#        [[179, 117, 105],
#         [180, 118, 106],
#         [182, 120, 108],
#         ...,
#         [179, 125, 121],
#         [183, 129, 125],
#         [184, 130, 126]],
#
#        [[175, 113, 101],
#         [176, 114, 102],
#         [177, 115, 103],
#         ...,
#         [167, 113, 109],
#         [171, 117, 113],
#         [172, 118, 114]]], dtype=uint8)

# %%
def show(image):
  plt.imshow(image[...,::-1])
  # convert from BGR to RGB

# %%
image.shape
# Out:
# (360, 640, 3)

# %%
plt.imshow(image)

# %%
show(image)

# %%
np.nan
# Out:
# nan

# %%
def place_square(im):
  x = 300
  y = 150
  r = 20
  n = 80
  
  R = 255
  G = 255
  B = 255
    
  im[y-r:y+r,x-r:x+r,:] = [R,G,B]
  im_copy = im.copy()
  im_copy[y-r:y+r,x-r:x+r,:] = 0
  
  patch = im_copy[y-n:y+n,x-n:x+n,:] 
  
  
  patch_hsv = rgb2hsv(patch)
  
  h1 = np.mean(patch_hsv[:,:,0])
  s1 = np.mean(patch_hsv[:,:,1])
  v1 = np.mean(patch_hsv[:,:,2])
  
  square = np.zeros((10,10,3))
  square[:,:,0] = R
  square[:,:,1] = G
  square[:,:,2] = B
  square_hsv = rgb2hsv(square)

  h2 = np.mean(square_hsv[:,:,0])
  s2 = np.mean(square_hsv[:,:,1])
  v2 = np.mean(square_hsv[:,:,2])

  # Differences
  dh = h1 - h2
  ds = s1 - s2
  dv = v1 - v2
  
  hsv_distance = np.sqrt( (h1-h2)**2 + (s1-s2)**2 + (v1-v2)**2)
  return im, patch, hsv_distance

# %%
square = np.zeros((10,10,3))
square[:,:,0] = 255
square[:,:,1] = 0
square[:,:,2] = 0
show(square)
square_hsv = rgb2hsv(square)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
square_hsv
# Out:
# array([[[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]],
#
#        [[  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.],
#         [  0.,   1., 255.]]])

# %%
image
# Out:
# array([[[135,  46,  93],
#         [135,  46,  93],
#         [135,  46,  93],
#         ...,
#         [176,  30,  77],
#         [176,  30,  77],
#         [176,  30,  77]],
#
#        [[146,  57, 104],
#         [146,  57, 104],
#         [146,  57, 104],
#         ...,
#         [189,  43,  90],
#         [189,  43,  90],
#         [189,  43,  90]],
#
#        [[151, 115, 158],
#         [151, 115, 158],
#         [151, 115, 158],
#         ...,
#         [144, 120, 149],
#         [144, 120, 149],
#         [144, 120, 149]],
#
#        ...,
#
#        [[176, 135, 126],
#         [177, 136, 127],
#         [182, 141, 132],
#         ...,
#         [187, 140, 137],
#         [191, 144, 141],
#         [192, 145, 142]],
#
#        [[179, 117, 105],
#         [180, 118, 106],
#         [182, 120, 108],
#         ...,
#         [179, 125, 121],
#         [183, 129, 125],
#         [184, 130, 126]],
#
#        [[175, 113, 101],
#         [176, 114, 102],
#         [177, 115, 103],
#         ...,
#         [167, 113, 109],
#         [171, 117, 113],
#         [172, 118, 114]]], dtype=uint8)

# %%
im2, patch,d = place_square(image)
show(im2)
print(d)
# Out:
# 254.2602250000659

# %%
show(patch)
